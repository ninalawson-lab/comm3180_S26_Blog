# %% [markdown]
# Story: Eileen Gu
#
# Why has Eileen Gu garnered so much media attention?
# * is it because she is a very decorated athlete?
# * is it because of the current political climate?
# * is it because she's kind of a super human?
#
# she is a person of interest to me because we are very similar
# * she is from the bay area and went to highschool near me
# * we grew up skiing on the same ski team in Lake Tahoe
# * we are the same ethnic makeup

# %% [markdown]
# In 2022, she earned 2 gold medals in big air and halfpipe and 1 silver meal in slopestyle- becoming one of the biggest stars of the winter games
#
# In 2026, so far she has earned a silver in big air, and slopestyle
#
# She now has five Olympic medals total, the most ever by a female freestyle skier in Olympic history
#
# She still has halfpipe, which she will compete in this Saturday, Feb 21st

# %%
# insert code about china's accomplishments in winter olympics
# female or male

# %% [markdown]
# Gold medals: She is the third most decorated WOMAN behind Wang Meng (4), and Zhou Yang (3)
# Total Medals: In terms of total medals with men and women, she is top 5 all-time

# %% [markdown]
# She competes in 3 different freeski disciplines, which makes her different than the others
#
# Most of China's medals come from short track speed skating, and most of their medals come from this sport
#
# China did not win it's first winter olympic gold medal until 2002

# %%
# look at the first time China won a gold medal in Winter Olympics
# compare that to when the US or Russia won their first
# plot the events they are good at (short track speed skating)

# %% [markdown]
# How has eileen's media attention differed in this environment compared to 2022 due to the political environment?

# %%
# look through bios to see what else you can add

# %%
import pandas as pd
import geopandas as gpd

import matplotlib.pyplot as plt

# %%
wolympics_df = pd.read_csv('data/winter_olympics_medals.csv')
wolympics_df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 wolympics_df = pd.read_csv('data/winter_olympics_medals.csv')
#       2 wolympics_df.shape
#
# File /opt/jupyterhub/share/jupyter/venv/python3_comm3180/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %%
wolympics_df.sample(20)
# Out:
#          year    type                           discipline  \
# 46836  2022.0  Winter             Figure Skating (Skating)
# 19542  1960.0  Winter             Nordic Combined (Skiing)
# 1550   1968.0  Winter              Speed Skating (Skating)
# 29921  1932.0  Winter              Speed Skating (Skating)
# 16821  1960.0  Winter              Ice Hockey (Ice Hockey)
# 34350  1998.0  Winter  Short Track Speed Skating (Skating)
# 17665  1992.0  Winter              Speed Skating (Skating)
# 20444  1988.0  Winter                             Biathlon
# 34959  1998.0  Winter              Ice Hockey (Ice Hockey)
# 29222  1994.0  Winter        Cross Country Skiing (Skiing)
# 36917  2006.0  Winter                                 Luge
# 1748   1976.0  Winter             Figure Skating (Skating)
# 9247   1972.0  Winter              Ice Hockey (Ice Hockey)
# 27822  2006.0  Winter        Cross Country Skiing (Skiing)
# 52815  2014.0  Winter              Ice Hockey (Ice Hockey)
# ...

# %%
wolympics_df[wolympics_df['as'] == 'Eileen Gu']
# Out:
#          year    type                 discipline                        event  \
# 60517  2020.0  Winter  Freestyle Skiing (Skiing)        Halfpipe, Girls (YOG)
# 60518  2020.0  Winter  Freestyle Skiing (Skiing)      Slopestyle, Girls (YOG)
# 60519  2020.0  Winter  Freestyle Skiing (Skiing)         Big Air, Girls (YOG)
# 60520  2022.0  Winter  Freestyle Skiing (Skiing)    Halfpipe, Women (Olympic)
# 60521  2022.0  Winter  Freestyle Skiing (Skiing)  Slopestyle, Women (Olympic)
# 60522  2022.0  Winter  Freestyle Skiing (Skiing)     Big Air, Women (Olympic)
#
#               as  athlete_id  noc team  place   tied   medal
# 60517  Eileen Gu      139214  CHN  NaN    1.0  False    Gold
# 60518  Eileen Gu      139214  CHN  NaN    2.0  False  Silver
# 60519  Eileen Gu      139214  CHN  NaN    1.0  False    Gold
# 60520  Eileen Gu      139214  CHN  NaN    1.0  False    Gold
# 60521  Eileen Gu      139214  CHN  NaN    2.0  False  Silver
# ...

# %%
wolympics_df[wolympics_df['noc'] == 'CHN']
# Out:
#          year    type                           discipline  \
# 322    1980.0  Winter             Figure Skating (Skating)
# 323    1984.0  Winter             Figure Skating (Skating)
# 975    1980.0  Winter              Speed Skating (Skating)
# 976    1980.0  Winter              Speed Skating (Skating)
# 977    1984.0  Winter              Speed Skating (Skating)
# ...       ...     ...                                  ...
# 63094  2022.0  Winter  Short Track Speed Skating (Skating)
# 63095  2022.0  Winter  Short Track Speed Skating (Skating)
# 63096  2022.0  Winter  Short Track Speed Skating (Skating)
# 63097  2022.0  Winter  Short Track Speed Skating (Skating)
# 63098  2022.0  Winter  Short Track Speed Skating (Skating)
#
#                                    event            as  athlete_id  noc  \
# 322             Singles, Women (Olympic)  Bao Zhenghua       80573  CHN
# 323             Singles, Women (Olympic)  Bao Zhenghua       80573  CHN
# ...

# %%
china_medals = wolympics_df[
    (wolympics_df['noc'] == 'CHN') &
    (wolympics_df['medal'].notna())
    ]
china_medals
# Out:
#          year    type                           discipline  \
# 1053   1994.0  Winter             Figure Skating (Skating)
# 1054   1998.0  Winter             Figure Skating (Skating)
# 3871   1992.0  Winter  Short Track Speed Skating (Skating)
# 7561   1998.0  Winter  Short Track Speed Skating (Skating)
# 7562   1998.0  Winter  Short Track Speed Skating (Skating)
# ...       ...     ...                                  ...
# 63059  2022.0  Winter                Snowboarding (Skiing)
# 63069  2022.0  Winter                 Skeleton (Bobsleigh)
# 63091  2022.0  Winter  Short Track Speed Skating (Skating)
# 63093  2022.0  Winter  Short Track Speed Skating (Skating)
# 63094  2022.0  Winter  Short Track Speed Skating (Skating)
#
#                                      event             as  athlete_id  noc  \
# 1053              Singles, Women (Olympic)        Chen Lu       80820  CHN
# 1054              Singles, Women (Olympic)        Chen Lu       80820  CHN
# ...

# %%
china_gold_medals = wolympics_df[
    (wolympics_df['noc'] == 'CHN') &
    (wolympics_df['medal'] == 'Gold')
    ]
china_gold_medals
# Out:
#          year    type                           discipline  \
# 34172  2010.0  Winter             Figure Skating (Skating)
# 34176  2010.0  Winter             Figure Skating (Skating)
# 34239  2002.0  Winter  Short Track Speed Skating (Skating)
# 34240  2002.0  Winter  Short Track Speed Skating (Skating)
# 38189  2006.0  Winter            Freestyle Skiing (Skiing)
# 41277  2006.0  Winter  Short Track Speed Skating (Skating)
# 41281  2010.0  Winter  Short Track Speed Skating (Skating)
# 41282  2010.0  Winter  Short Track Speed Skating (Skating)
# 41284  2010.0  Winter  Short Track Speed Skating (Skating)
# 46827  2022.0  Winter            Freestyle Skiing (Skiing)
# 46875  2022.0  Winter            Freestyle Skiing (Skiing)
# 48755  2010.0  Winter  Short Track Speed Skating (Skating)
# 48809  2010.0  Winter  Short Track Speed Skating (Skating)
# 48814  2010.0  Winter  Short Track Speed Skating (Skating)
# 48815  2010.0  Winter  Short Track Speed Skating (Skating)
# ...

# %%
china_gold_medals = wolympics_df[
    (wolympics_df['noc'] == 'CHN') &
    (wolympics_df['medal'] == 'Gold')
]

china_gold_medals = china_medals.sort_values(by='year')

china_gold_medals
# Out:
#          year    type                           discipline  \
# 3871   1992.0  Winter  Short Track Speed Skating (Skating)
# 7567   1992.0  Winter              Speed Skating (Skating)
# 7568   1992.0  Winter              Speed Skating (Skating)
# 1053   1994.0  Winter             Figure Skating (Skating)
# 7687   1994.0  Winter  Short Track Speed Skating (Skating)
# ...       ...     ...                                  ...
# 63059  2022.0  Winter                Snowboarding (Skiing)
# 63069  2022.0  Winter                 Skeleton (Bobsleigh)
# 63091  2022.0  Winter  Short Track Speed Skating (Skating)
# 63093  2022.0  Winter  Short Track Speed Skating (Skating)
# 63094  2022.0  Winter  Short Track Speed Skating (Skating)
#
#                                      event            as  athlete_id  noc  \
# 3871           500 metres, Women (Olympic)        Li Yan       81673  CHN
# 7567           500 metres, Women (Olympic)     Ye Qiaobo       83085  CHN
# ...

# %%
china_and_usa_filter = wolympics_df['noc'].isin(['USA','CHN'])
medal_filter = -wolympics_df['medal'].isna()

# %%
china_usa_medals_df = wolympics_df[china_and_usa_filter & medal_filter].groupby(['year','noc'])['medal'].size()

# %%
china_usa_medals_df.unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
countries_filter = wolympics_df['noc'].isin(['USA','CHN','NOR','GER'])
medal_filter = -wolympics_df['medal'].isna()

# %%
countries_df = wolympics_df[countries_filter & medal_filter].groupby(['year','noc'])['medal'].size()

# %%
countries_df.unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
countries_df.unstack().plot(
    kind='bar',
    color=['#d62728', '#bdbdbd', '#969696', '#636363']
)
# Out:
# <Axes: xlabel='year'>

# %%
china_2022 = wolympics_df[
    (wolympics_df['year'] == 2022) &
    (wolympics_df['noc'] == 'CHN') &
    (wolympics_df['medal'].notna())
]

# %%
china_medal_counts = china_2022.groupby('as')['medal'].count()
china_medal_counts.sort_values(ascending=False)
# Out:
# as
# Eileen Gu        3
# Fan Kexin        2
# Qu Chunyu        2
# Qi Guangpu       2
# Ren Ziwei        2
# Xu Mengtao       2
# Zhang Yuting     2
# Su Yiming        2
# Gao Tingyu       1
# Jia Zongyang     1
# Li Wenlong       1
# Han Cong         1
# Han Yutong       1
# Wu Dajing        1
# Sui Wenjing      1
# Yan Wengang      1
# Zhang Chutong    1
# Name: medal, dtype: int64

# %%
ax = china_medal_counts.sort_values(ascending=False).plot(kind='bar')

for i, athlete in enumerate(china_medal_counts.sort_values(ascending=False).index):
    if 'Eileen Gu' in athlete:
        ax.patches[i].set_color('red')
    else:
        ax.patches[i].set_color('gray')

# %%
china_2022 = wolympics_df[
    (wolympics_df['year'] == 2022) &
    (wolympics_df['noc'] == 'CHN') &
    (wolympics_df['medal'].notna())
]

# %%
china_2022.groupby('as')['event'].unique()
# Out:
# as
# Eileen Gu        [Halfpipe, Women (Olympic), Slopestyle, Women ...
# Fan Kexin        [2,000 metres Relay, Mixed (Olympic), 3,000 me...
# Gao Tingyu                             [500 metres, Men (Olympic)]
# Han Cong                                  [Pairs, Mixed (Olympic)]
# Han Yutong                   [3,000 metres Relay, Women (Olympic)]
# Jia Zongyang                       [Team Aerials, Mixed (Olympic)]
# Li Wenlong                           [1,000 metres, Men (Olympic)]
# Qi Guangpu       [Team Aerials, Mixed (Olympic), Aerials, Men (...
# Qu Chunyu        [2,000 metres Relay, Mixed (Olympic), 3,000 me...
# Ren Ziwei        [2,000 metres Relay, Mixed (Olympic), 1,000 me...
# Su Yiming        [Slopestyle, Men (Olympic), Big Air, Men (Olym...
# Sui Wenjing                               [Pairs, Mixed (Olympic)]
# Wu Dajing                    [2,000 metres Relay, Mixed (Olympic)]
# Xu Mengtao       [Team Aerials, Mixed (Olympic), Aerials, Women...
# ...

# %%
china_2022_individual = china_2022[
    ~china_2022['event'].str.contains('Relay|Team|Pairs', case=False, na=False)]

# %%
china_2022_individual.groupby('as')['event'].unique()
# Out:
# as
# Eileen Gu      [Halfpipe, Women (Olympic), Slopestyle, Women ...
# Gao Tingyu                           [500 metres, Men (Olympic)]
# Li Wenlong                         [1,000 metres, Men (Olympic)]
# Qi Guangpu                              [Aerials, Men (Olympic)]
# Ren Ziwei                          [1,000 metres, Men (Olympic)]
# Su Yiming      [Slopestyle, Men (Olympic), Big Air, Men (Olym...
# Xu Mengtao                            [Aerials, Women (Olympic)]
# Yan Wengang                            [Skeleton, Men (Olympic)]
# Name: event, dtype: object

# %%
event_counts = china_2022_individual.groupby('as')['event'].nunique()

event_counts[event_counts > 1]
# Out:
# as
# Eileen Gu    3
# Su Yiming    2
# Name: event, dtype: int64

# %%
medals_2022 = wolympics_df[
    (wolympics_df['year'] == 2022) &
    (wolympics_df['medal'].notna())
]
medals_2022_individual = medals_2022[
    ~medals_2022['event'].str.contains('Relay|Team|Pairs', case=False, na=False)
]

# %%
global_event_counts = (
    medals_2022_individual
    .groupby('as')['event']
    .nunique()
    .sort_values(ascending=False)
)

global_event_counts.head(10)
# Out:
# as
# Marte Olsbu Røiseland     4
# Miho Takagi               3
# Quentin Fillon Maillet    3
# Suzanne Schulting         3
# Aleksandr Bolshunov       3
# Irene Schouten            3
# Johannes Thingnes Bø      3
# Eileen Gu                 3
# Therese Johaug            3
# Tarjei Bø                 2
# Name: event, dtype: int64

# %%
global_event_counts[global_event_counts >= 3]
# Out:
# as
# Marte Olsbu Røiseland     4
# Miho Takagi               3
# Quentin Fillon Maillet    3
# Suzanne Schulting         3
# Aleksandr Bolshunov       3
# Irene Schouten            3
# Johannes Thingnes Bø      3
# Eileen Gu                 3
# Therese Johaug            3
# Name: event, dtype: int64

# %%
global_event_counts.value_counts().sort_index()
# Out:
# event
# 1    320
# 2     33
# 3      8
# 4      1
# Name: count, dtype: int64

# %%
global_event_counts.value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='event'>

# %%
bios = pd.read_csv('data/bios.csv')
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios[bios['name'] == 'Eileen Gu']
# Out:
#         athlete_id       name   born_date      born_city born_region  \
# 135995      139214  Eileen Gu  2003-09-03  San Francisco  California
#
#        born_country                         NOC  height_cm  weight_kg  \
# 135995          USA  People's Republic of China        NaN        NaN
#
#        died_date
# 135995       NaN

# %%
bios = pd.read_csv('data/bios.csv')
